# %% [markdown]
# # Artificial Intelligence And Machine Learning INTERNSHIP
# ### Day NO:-6
# ### Date - 30-05-19

# %% [markdown]
# ## Task 1:-
#
# #### Problem Statements:-
#
# Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd
class DataList:
    def data_list1(filename):
            df=pd.read_csv(filename)
            return df
    def unique(l1):
        u=(np.unique(l1))
        return u
    def data_frame(u,df):
        l3=[]
        for i in range(0, len(u)):
            sum=0
            for j in df.values:
                if(j[10]==u[i]):
                    sum=sum+1
            l3.append(sum)
        return(l3)
    def pie_dra(a,b):
        fidl,axl=plt.subplots()
        axl.pie(b,labels=a,shadow=True,startangle=90)
        axl.axis('equal')
        plt.show()

# %%
df=DataList.data_list1('DataFile/Match.csv')
l1=[]
for i in df.values:
    l1.append(i[10])
u=DataList.unique(l1)
dff=DataList.data_frame(u,df)
DataList.pie_dra(u,dff)

# %% [markdown]
# ## Task 2:-
#
# #### Problem Statements:-
#
# Draw a bar graph for number of matches won (i,e.consider win if the team wins both the toss and match)  for the team “Mumbai Indians” for all years

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pandas as pd
class DataList:
    def data_list1(filename):
        df=pd.read_csv(filename)
        return df
    def unique(l1):
        u=(np.unique(l1))
        return u
    def won_matches(df,u):
        l2=[]
        for i in range(0, len(u)):
            sum=0
            for j in df.values:
                if(j[10]=='Mumbai Indians' and j[9]=='Mumbai Indians' and j[5]==u[i]):
                    sum=sum+1
            l2.append(sum)
        return l2
    def bar_graph(u,w):
        x=1/2
        plt.bar(u,w,x,color=('Black','Purple','Red'))
        plt.xlabel('Years')
        plt.ylabel('Won Matches')
        plt.title('Grahp:-A')
        plt.show

# %%
df=DataList.data_list1('DataFile/Match.csv')
l1=[]
for i in df.values:
    l1.append(i[5])
u=DataList.unique(l1)
w=DataList.won_matches(df,u)
DataList.bar_graph(u,w)
